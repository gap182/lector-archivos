# %%
import numpy as np

# %%
import pandas as pd

# %%
ax=pd.read_csv('supercal.fitres',delim_whitespace=True, skiprows=6)

# %%
ax
ax1=ax[['CID','zHD','zHDERR','z','zERR','PKMJD','PKMJDERR','x1','x1ERR','c','cERR','mB','mBERR','x0','x0ERR','FITCHI2','FITPROB','TGAPMAX', 'MUERR','MURES']]

# %%
axfit=ax1[(ax1['zHD']>0.01) & (ax1['zHD']<0.4)&(ax1['x1']<3.0)&(ax1['x1']>-3.0)&(ax1['c']<0.3)&(ax1['c']>-0.3)&(ax1['FITPROB']>0.001)&(ax1['PKMJDERR']<2.0)&(ax1['x1ERR']<1.5)&(ax1['mBERR']<0.2)]

# %%
# Out:
# Empty DataFrame
# Columns: [CID, zHD, zHDERR, z, zERR, PKMJD, PKMJDERR, x1, x1ERR, c, cERR, mB, mBERR, x0, x0ERR, FITCHI2, FITPROB, TGAPMAX, MUERR, MURES]
# Index: []

# %%
axfit
# Out:
#          CID      zHD   zHDERR        z     zERR      PKMJD  PKMJDERR  \
# 0        744  0.12694  0.00001  0.12825  0.00001  53612.910     0.767
# 1       1112  0.25609  0.00001  0.25761  0.00001  53630.145     0.698
# 2       1241  0.08848  0.00001  0.08979  0.00001  53635.367     0.078
# 3       1371  0.11797  0.00001  0.11934  0.00001  53633.305     0.107
# 4       1580  0.18322  0.00001  0.18400  0.00001  53634.039     0.208
# 5       1794  0.14070  0.00001  0.14191  0.00001  53624.680     0.547
# 6       2031  0.15186  0.00001  0.15300  0.00001  53636.891     0.140
# 7       2102  0.09401  0.00001  0.09510  0.00001  53620.195     0.489
# 8       2165  0.28662  0.00001  0.28800  0.00001  53634.355     0.488
# 9       2422  0.26349  0.00001  0.26500  0.00001  53639.633     0.363
# 10      2635  0.14310  0.00001  0.14370  0.00001  53640.273     0.175
# 11      2689  0.16035  0.00001  0.16149  0.00001  53637.051     0.187
# ...

# %%
axfit[axfit['CID']=='10434']
# Out:
#        CID      zHD   zHDERR        z     zERR      PKMJD  PKMJDERR        x1  \
# 246  10434  0.10288  0.00001  0.10416  0.00001  53696.461     0.043 -0.016396
#
#       x1ERR        c      cERR       mB     mBERR        x0     x0ERR  \
# 246  0.1582 -0.08921  0.023914  18.8891  0.029147  0.000499  0.000014
#
#      FITCHI2  FITPROB  TGAPMAX   MUERR  MURES
# 246   7.0172    0.934  11.7347  0.0564  0.124

# %%
ax[ax['CID']=='10434']
# Out:
#     VARNAMES:    CID  CIDint  IDSURVEY  TYPE FIELD      zHD   zHDERR        z  \
# 246       SN:  10434   10434         1   120   82S  0.10288  0.00001  0.10416
#
#         zERR   ...            RA      DECL  TGAPMAX       MU   MUERR  MURES  \
# 246  0.00001   ...    -30.044159 -1.193738  11.7347  38.5273  0.0564  0.124
#
#      MUPULL   sbar   cbar  ERRCODE
# 246   2.194 -0.113 -0.048        0
#
# [1 rows x 41 columns]

# %%
ax[ax['TGAPMAX']>5]
# Out:
#      VARNAMES:        CID  CIDint  IDSURVEY  TYPE    FIELD      zHD   zHDERR  \
# 0          SN:        744     744         1   120      82N  0.12694  0.00001
# 1          SN:       1112    1112         1   120      82S  0.25609  0.00001
# 2          SN:       1241    1241         1   120      82S  0.08848  0.00001
# 3          SN:       1371    1371         1   120      82S  0.11797  0.00001
# 4          SN:       1580    1580         1   120      82S  0.18322  0.00001
# 5          SN:       1794    1794         1   120      82N  0.14070  0.00001
# 6          SN:       2031    2031         1   120      82S  0.15186  0.00001
# 7          SN:       2102    2102         1   120      82S  0.09401  0.00001
# 8          SN:       2165    2165         1   120      82N  0.28662  0.00001
# 9          SN:       2422    2422         1   120      82N  0.26349  0.00001
# 10         SN:       2635    2635         1   120      82S  0.14310  0.00001
# ...
